# %% [markdown]
# ## Análise da performance dos índices no pós pandemia

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import investpy
import matplotlib.pyplot as plt

# %%
investpy.indices.get_indices(country="Brazil")
# Out:
#    country                                               name  \
# 0   brazil                                MSCI Brazil Net USD
# 1   brazil                                          DJ Brazil
# 2   brazil                                       TR Brazil 50
# 3   brazil                              MSCI Brazil Price USD
# 4   brazil                            DJ Brazil Titans 20 ADR
# 5   brazil                              BNY Mellon Brazil ADR
# 6   brazil                           BNY Mellon Brazil ADR TR
# 7   brazil                      BNY Mellon Brazil Classic ADR
# 8   brazil                   BNY Mellon Brazil Classic ADR TR
# 9   brazil                                FTSE RAFI Brazil 50
# 10  brazil                                  MSCI Brazil 10 40
# 11  brazil                       DJ BRIC Brazil 15 Capped NTR
# 12  brazil                              DJ BRIC Brazil 15 USD
# 13  brazil                              DJ BRIC Brazil 15 EUR
# ...

# %%
names = ['Bovespa','Small Cap Index','Bovespa Dividend']

index = pd.DataFrame()

for n in names:
    index[n] = investpy.get_index_historical_data(index= n,
    country='Brazil',
    from_date='01/01/2020',
    to_date='01/06/2021')['Close']
    
index = (index/index.iloc[0])*100
index.plot(figsize= (20,10))
plt.show()

# %%
names2 = ['Bovespa','Consumption','Basic Materials','Real Estate','Electrical Energy','Industrial Sector','Financials']
index2 = pd.DataFrame()

for n in names2:
    index2[n] = investpy.get_index_historical_data(index= n,
    country='Brazil',
    from_date='01/01/2020',
    to_date='01/06/2021')['Close']
    
index2 = (index2/index2.iloc[0])*100
index2.plot(figsize= (20,10))
plt.show()
